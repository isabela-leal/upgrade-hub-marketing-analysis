# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargamos nuestro dataset limpio
df = pd.read_csv('C:/Users/Propietario/OneDrive/Escritorio/DataAnalysis2025/Proyecto-1/marketingcampaigns_cleaned.csv')

# %% [markdown]
# ¿Que canal de marketing se utiliza con mayor frecuencia y cual genera mejor ROI?

# %%
#Visualizamos la frecuencia de los canales de marketing
channel_counts = df['channel'].value_counts()

# Creacion del grafico de la frecuencia de los canales de marketing
plt.figure(figsize=(10,6))
sns.barplot(x=channel_counts.index, y=channel_counts.values, palette="Blues")
plt.title('Frecuencia de Uso de Canales de Marketing', fontsize=14)
plt.xlabel('Canal de Marketing')
plt.ylabel('Número de Campañas')
plt.xticks(rotation=45)
plt.show()

# Comparamos el rendimiento de cada canal en términos de ROI
plt.figure(figsize=(12,6))
sns.boxplot(x='channel', y='roi', data=df, palette="Blues")
plt.title('Distribución del ROI por Canal de Marketing', fontsize=14)
plt.xlabel('Canal de Marketing')
plt.ylabel('ROI')
plt.xticks(rotation=45)
plt.show()

# Comparación de ROI por canal segmentado por tipo de campaña
plt.figure(figsize=(12,6))
sns.boxplot(x='channel', y='roi', hue='type', data=df, palette="Blues")
plt.title('Distribución del ROI por Canal y Tipo de Campaña', fontsize=14)
plt.xlabel('Canal de Marketing')
plt.ylabel('ROI')
plt.xticks(rotation=45)
plt.show()

# Comparación de ROI por canal segmentado por 'target_audience'
plt.figure(figsize=(12,6))
sns.boxplot(x='channel', y='roi', hue='target_audience', data=df, palette="Blues")
plt.title('Distribución del ROI por Canal y Audiencia Objetivo', fontsize=14)
plt.xlabel('Canal de Marketing')
plt.ylabel('ROI')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Propietario\AppData\Local\Temp\ipykernel_5124\3315429621.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=channel_counts.index, y=channel_counts.values, palette="Blues")
# C:\Users\Propietario\AppData\Local\Temp\ipykernel_5124\3315429621.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='channel', y='roi', data=df, palette="Blues")

# %% [markdown]
# ¿Que tipo de campaña genera mas ingresos en promedio y cual tiene mejor converision?

# %%
#Calculamos ls ingresos promedio y la tasa de conversión promedio por tipo de campaña
campaign_metrics = df.groupby('type').agg(
    average_revenue=('revenue', 'mean'),
    average_conversion_rate=('conversion_rate', 'mean')
).reset_index()

#Creamos grafico para los ingresos promedio por tipo de campaña
plt.figure(figsize=(12,6))
sns.barplot(x='type', y='average_revenue', data=campaign_metrics, palette="Blues")
plt.title('Ingresos Promedio por Tipo de Campaña', fontsize=14)
plt.xlabel('Tipo de Campaña')
plt.ylabel('Ingresos Promedio')
plt.xticks(rotation=45)
plt.show()

# Visualizamos la tasa de conversión promedio por tipo de campaña
plt.figure(figsize=(12,6))
sns.barplot(x='type', y='average_conversion_rate', data=campaign_metrics, palette="Blues")
plt.title('Tasa de Conversión Promedio por Tipo de Campaña', fontsize=14)
plt.xlabel('Tipo de Campaña')
plt.ylabel('Tasa de Conversión Promedio')
plt.xticks(rotation=45)
plt.show()

#Correlación entre ingresos y tasa de conversión 
plt.figure(figsize=(10,6))
sns.scatterplot(x='average_revenue', y='average_conversion_rate', data=campaign_metrics, palette="Blues", s=100)
plt.title('Correlación entre Ingresos Promedio y Tasa de Conversión por Tipo de Campaña', fontsize=14)
plt.xlabel('Ingresos Promedio')
plt.ylabel('Tasa de Conversión Promedio')
plt.show()
# Out:
# C:\Users\Propietario\AppData\Local\Temp\ipykernel_5124\2351748270.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='type', y='average_revenue', data=campaign_metrics, palette="Blues")
# C:\Users\Propietario\AppData\Local\Temp\ipykernel_5124\2351748270.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='type', y='average_conversion_rate', data=campaign_metrics, palette="Blues")
# C:\Users\Propietario\AppData\Local\Temp\ipykernel_5124\2351748270.py:27: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='average_revenue', y='average_conversion_rate', data=campaign_metrics, palette="Blues", s=100)

# %% [markdown]
# ¿Como se distribuye el ROI entre las campañas? ¿Que factores estan asociados con un ROI alto?

# %%
#Histograma del ROI
plt.figure(figsize=(10,6))
sns.histplot(df['roi'], kde=True, color='blue', bins=30)
plt.title('Distribución del ROI', fontsize=14)
plt.xlabel('ROI')
plt.ylabel('Frecuencia')
plt.show()

#Boxplot del ROI
plt.figure(figsize=(10,6))
sns.boxplot(x=df['roi'], color='blue')
plt.title('Distribución del ROI (Boxplot)', fontsize=14)
plt.xlabel('ROI')
plt.show()


#Heatmap de correlación entre ROI y otras variables numéricas
correlation_matrix = df[['roi', 'budget', 'revenue', 'conversion_rate']].corr()
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap="Blues", vmin=-1, vmax=1, linewidths=0.5)
plt.title('Correlación entre ROI y Otras Variables Numéricas', fontsize=14)
plt.show()

#Gráfico de dispersión entre ROI y presupuesto
plt.figure(figsize=(10,6))
sns.scatterplot(x='budget', y='roi', data=df, color='blue')
plt.title('Relación entre Presupuesto y ROI', fontsize=14)
plt.xlabel('Presupuesto')
plt.ylabel('ROI')
plt.show()

#Gráfico de dispersión entre ROI y tasa de conversión
plt.figure(figsize=(10,6))
sns.scatterplot(x='conversion_rate', y='roi', data=df, color='blue')
plt.title('Relación entre Tasa de Conversión y ROI', fontsize=14)
plt.xlabel('Tasa de Conversión')
plt.ylabel('ROI')
plt.show()

#Gráfico de dispersión entre ROI y canal 
plt.figure(figsize=(10,6))
sns.boxplot(x='channel', y='roi', data=df, palette="Blues")
plt.title('Distribución del ROI por Canal de Marketing', fontsize=14)
plt.xlabel('Canal de Marketing')
plt.ylabel('ROI')
plt.xticks(rotation=45)
plt.show()

#Gráfico de dispersión entre ROI y tipo de campaña
plt.figure(figsize=(10,6))
sns.boxplot(x='type', y='roi', data=df, palette="Blues")
plt.title('Distribución del ROI por Tipo de Campaña', fontsize=14)
plt.xlabel('Tipo de Campaña')
plt.ylabel('ROI')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Propietario\AppData\Local\Temp\ipykernel_5124\1939629399.py:42: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='channel', y='roi', data=df, palette="Blues")
# C:\Users\Propietario\AppData\Local\Temp\ipykernel_5124\1939629399.py:51: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='type', y='roi', data=df, palette="Blues")

# %% [markdown]
# ¿Hay diferencias en la tasa de conversion entre audiencias B2B Y B2C?

# %%
#Boxplot comparativo entre la tasa de conversión de B2B y B2C
plt.figure(figsize=(10,6))
sns.boxplot(x='target_audience', y='conversion_rate', data=df, palette="Blues")
plt.title('Comparación de Tasa de Conversión entre Audiencias B2B y B2C', fontsize=14)
plt.xlabel('Audiencia')
plt.ylabel('Tasa de Conversión')
plt.show()

#Promedio de la tasa de conversión por audiencia, canal y tipo de campaña
audience_conversion = df.groupby(['target_audience', 'channel']).agg(
    avg_conversion_rate=('conversion_rate', 'mean')
).reset_index()

#Creamos su respectivo grafico
plt.figure(figsize=(12,6))
sns.barplot(x='channel', y='avg_conversion_rate', hue='target_audience', data=audience_conversion, palette="Blues")
plt.title('Tasa de Conversión Promedio por Audiencia y Canal', fontsize=14)
plt.xlabel('Canal')
plt.ylabel('Tasa de Conversión Promedio')
plt.xticks(rotation=45)
plt.show()

#Promedio de la tasa de conversión por audiencia y tipo de campaña
audience_campaign_conversion = df.groupby(['target_audience', 'type']).agg(
    avg_conversion_rate=('conversion_rate', 'mean')
).reset_index()

#Y sacamos el grafico
plt.figure(figsize=(12,6))
sns.barplot(x='type', y='avg_conversion_rate', hue='target_audience', data=audience_campaign_conversion, palette="Blues")
plt.title('Tasa de Conversión Promedio por Audiencia y Tipo de Campaña', fontsize=14)
plt.xlabel('Tipo de Campaña')
plt.ylabel('Tasa de Conversión Promedio')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Propietario\AppData\Local\Temp\ipykernel_5124\854314683.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='target_audience', y='conversion_rate', data=df, palette="Blues")

# %% [markdown]
# ¿Que campaña tiene el mayor beneficio neto (net_profit)? ¿Que caracteristicas la hacen exitosa?

# %%
#Calcular beneficio neto y ordenar por beneficio neto
df['net_profit'] = df['revenue'] - df['budget']

#Ordenar las campañas por beneficio neto 
top_campaigns = df[['campaign_name', 'net_profit', 'budget', 'revenue', 'roi', 'conversion_rate', 'type', 'target_audience', 'channel']].sort_values(by='net_profit', ascending=False).head(10)

# Miramos las 10 campañas con mayor beneficio nneto
print(top_campaigns[['campaign_name', 'net_profit', 'budget', 'revenue', 'roi', 'conversion_rate', 'type', 'target_audience', 'channel']])

# Empleamos un gráfico de barras de beneficio neto para las top 10 campañas
plt.figure(figsize=(12,6))
sns.barplot(x='net_profit', y='campaign_name', data=top_campaigns, palette="Blues")
plt.title('Top 10 Campañas por Beneficio Neto', fontsize=14)
plt.xlabel('Beneficio Neto')
plt.ylabel('Campaña')
plt.show()

#Gráfico de barras comparativo de características (canal, tipo, audiencia) de las top 10 campañas. Analizamos la distribuciones

# Distribución por canal
plt.figure(figsize=(12,6))
sns.countplot(y='channel', data=top_campaigns, palette="Blues")
plt.title('Distribución de Canales en las Top 10 Campañas por Beneficio Neto', fontsize=14)
plt.xlabel('Número de Campañas')
plt.ylabel('Canal')
plt.show()

# Distribución por tipo de campaña
plt.figure(figsize=(12,6))
sns.countplot(y='type', data=top_campaigns, palette="Blues")
plt.title('Distribución de Tipos de Campañas en las Top 10 Campañas por Beneficio Neto', fontsize=14)
plt.xlabel('Número de Campañas')
plt.ylabel('Tipo de Campaña')
plt.show()

# Distribución por audiencia objetivo
plt.figure(figsize=(12,6))
sns.countplot(y='target_audience', data=top_campaigns, palette="Blues")
plt.title('Distribución de Audiencias en las Top 10 Campañas por Beneficio Neto', fontsize=14)
plt.xlabel('Número de Campañas')
plt.ylabel('Audiencia Objetivo')
plt.show()
# Out:
#                                 campaign_name  net_profit    budget  \
# 492            advanced systematic complexity   987859.73   1873.52
# 880              balanced optimizing software   987359.82  10297.36
# 699            object-based didactic intranet   979827.40   6430.70
# 203  reverse-engineered static infrastructure   974958.97  12246.32
# 193       sharable upward-trending initiative   973355.11  20951.30
# 170                realigned radical hardware   965199.63  34512.86
# 902              up-sized dedicated workforce   964497.81  26043.99
# 791   function-based homogeneous productivity   963838.00  11711.34
# 825  right-sized transitional standardization   960202.70   9929.80
# 907       implemented logistical architecture   958135.52  15386.79
#
#        revenue   roi  conversion_rate          type target_audience    channel
# 492  989733.25  0.95             0.54       podcast             b2c    organic
# ...

# %% [markdown]
# ¿Existe correlacion entre el presupuesto (budget) y los ingresos (revenue)?

# %%
#Gráfico de dispersión entre presupuesto y ingresos
plt.figure(figsize=(10, 6))
sns.scatterplot(x='budget', y='revenue', data=df, palette="Blues", hue='channel', style='type', s=100)
print()

#Añadimos línea de tendencia 
sns.regplot(x='budget', y='revenue', data=df, scatter=False, color='blue', line_kws={'lw': 2})

#Terminamos el grafico
plt.title('Relación entre Presupuesto y Ingresos', fontsize=16)
plt.xlabel('Presupuesto', fontsize=14)
plt.ylabel('Ingresos', fontsize=14)
plt.legend(title='Canal / Tipo', loc='upper left', fontsize=8)
plt.grid(True)
plt.show()

# %% [markdown]
# ¿Que campañas tienen un ROI mayor a 0.5 y ingresos encim,a de 500,000?

# %%
#Campañas con ROI > 0.5 y ingresos > 500,000
high_performance_campaigns = df[(df['roi'] > 0.5) & (df['revenue'] > 500000)]
print(high_performance_campaigns[['campaign_name', 'roi', 'revenue', 'budget', 'conversion_rate', 'type', 'target_audience', 'channel']])

#Creacion de ráfico de cuadrantes: ROI vs Ingresos
plt.figure(figsize=(12, 8))
sns.scatterplot(x='roi', y='revenue', data=high_performance_campaigns, hue='channel', style='type', s=100, palette='Blues')

#Añadimos líneas de referencia para el filtro de ROI y ingresos
plt.axhline(y=500000, color='red', linestyle='--', label='Ingreso > 500,000')
plt.axvline(x=0.5, color='red', linestyle='--', label='ROI > 0.5')

#Terminamos con el grafico
plt.title('Campañas de Alto Rendimiento (ROI > 0.5 y Ingresos > 500,000)', fontsize=16)
plt.xlabel('ROI', fontsize=14)
plt.ylabel('Ingresos', fontsize=14)
plt.legend(title='Canal / Tipo', loc='upper left', fontsize=12)
plt.grid(True)
plt.show()
# Out:
#                                     campaign_name   roi    revenue    budget  \
# 1              de-engineered analyzing task-force  0.74  516609.10  17712.98
# 5          upgradable transitional data-warehouse  0.59  558302.11  75569.28
# 9                    intuitive responsive support  0.81  563280.30   1816.22
# 12                  networked even-keeled toolset  0.58  680416.90  49375.81
# 21    self-enabling human-resource infrastructure  0.69  974038.96  60274.59
# ...                                           ...   ...        ...       ...
# 998                   operative tangible firmware  0.80  613448.30  77555.40
# 1003       upgradable transitional data-warehouse  0.59  558302.11  44640.33
# 1009           de-engineered analyzing task-force  0.74  516609.10  17712.98
# 1013       upgradable transitional data-warehouse  0.59  558302.11  75569.28
# 1017                 intuitive responsive support  0.81  563280.30   1816.22
#
# ...

# %% [markdown]
# ¿Existen patrones estacionales o temporales en el rendimiento de las campañas?

# %%
#Componentes temporales 
#Extraemos componentes temporales de la fecha
df['start_date'] = pd.to_datetime(df['start_date'])  # Asegurarnos de que 'start_date' sea de tipo datetime

df['month'] = df['start_date'].dt.month  # Extraer el mes
df['quarter'] = df['start_date'].dt.quarter  # Extraer el trimestre
df['year'] = df['start_date'].dt.year  # Extraer el año

df[['start_date', 'month', 'quarter', 'year']].head()
# Out:
#   start_date  month  quarter  year
# 0 2023-04-01      4        2  2023
# 1 2023-02-15      2        1  2023
# 2 2022-12-20     12        4  2022
# 3 2022-09-26      9        3  2022
# 4 2023-07-07      7        3  2023

# %%
#Creamos grafico de linea temporalñ del rendimiento de las campañas

#Agrupar por año y mes para calcular la media de ROI e ingresos
monthly_performance = df.groupby(['year', 'month']).agg({'roi': 'mean', 'revenue': 'mean'}).reset_index()

#Gráfico de línea temporal para analizar el rendimiento a lo largo del tiempo
plt.figure(figsize=(12, 6))

#Gráfico de ROI mensual
sns.lineplot(data=monthly_performance, x='month', y='roi', marker='o', label='ROI', color='blue')

# Gráfico de Ingresos mensuales
sns.lineplot(data=monthly_performance, x='month', y='revenue', marker='o', label='Ingresos', color='green')

# Damos forma al grafico
plt.title('Rendimiento mensual de las campañas (ROI e Ingresos)', fontsize=16)
plt.xlabel('Mes', fontsize=14)
plt.ylabel('Valor', fontsize=14)
plt.legend(title='Métricas', fontsize=12)
plt.grid(True)
plt.xticks(range(1, 13))  # Aseguramos que los meses estén bien representados
plt.show()

# %%
#Mapa de calor para el rendimiento mensual por tipo de campaña
#Agrupar por año, mes y tipo de campaña para obtener el rendimiento 
monthly_campaign_performance = df.groupby(['year', 'month', 'type']).agg({'roi': 'mean', 'revenue': 'mean'}).reset_index()

#Pivoteamos los datos para crear un formato adecuado para un heatmap 
heatmap_data = monthly_campaign_performance.pivot_table(index='month', columns='type', values='roi', aggfunc='mean')

#Creacion de mapa de calor
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, cmap='Blues', fmt='.2f', cbar_kws={'label': 'Promedio ROI'}, linewidths=0.5)

#Damos la forma que queremos a nuestro grafico
plt.title('Heatmap del ROI mensual por tipo de campaña', fontsize=16)
plt.xlabel('Tipo de Campaña', fontsize=14)
plt.ylabel('Mes', fontsize=14)
plt.show()

# %%
#Analisis de rendimiento por trimestre
#Agrupar por año y trimestre para analizar el rendimiento por trimestre
quarterly_performance = df.groupby(['year', 'quarter']).agg({'roi': 'mean', 'revenue': 'mean'}).reset_index()

#Gráfico de línea temporal por trimestre para ver la tendencia
plt.figure(figsize=(12, 6))

#Gráfico de ROI trimestral
sns.lineplot(data=quarterly_performance, x='quarter', y='roi', marker='o', label='ROI', color='blue')

#Gráfico de Ingresos trimestrales
sns.lineplot(data=quarterly_performance, x='quarter', y='revenue', marker='o', label='Ingresos', color='green')

#Terminamios nuestro grafico
plt.title('Rendimiento trimestral de las campañas (ROI e Ingresos)', fontsize=16)
plt.xlabel('Trimestre', fontsize=14)
plt.ylabel('Valor', fontsize=14)
plt.legend(title='Métricas', fontsize=12)
plt.grid(True)
plt.show()
